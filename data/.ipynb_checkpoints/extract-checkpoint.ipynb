# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import json
import numpy as np

# %%
places_urls=[]
url = 'https://www.fis-ski.com/DB/cross-country/calendar-results.html?eventselection=&place=&sectorcode=CC&seasoncode=2020&categorycode=WC&disciplinecode=&gendercode=&racedate=&racecodex=&nationcode=&seasonmonth=X-2020&saveselection=-1&seasonselection='
response = requests.get(url, timeout=5)
content = BeautifulSoup(response.content, "html.parser")
tableHeader = content.find('div',id='calendardata')
rows = tableHeader.find_all('a', class_='pr-1 g-lg-1 g-md-1 g-sm-2 hidden-xs justify-left')
for row in rows:
    places_urls.append(str(row.get('href')))
    print (str(row.get('href')))
# Out:
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45161&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45164&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45165&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45166&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45167&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45170&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45168&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45169&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45171&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45173&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45174&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45175&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45176&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45180&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45177&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45178&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45179&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45181&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45182&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45183&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45184&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45185&seasoncode=2020
# https://www.fis-ski.com/DB/general/event-details.html?sectorcode=CC&eventid=45186&seasoncode=2020

# %% [markdown]
# Sätter season till rätt säsong utifrån url

# %%
tmp_url=places_urls[-1:]
season=tmp_url[0][-4:]
# Out:
# '2020'

# %%
races_urls=[]
for url in places_urls:
    response = requests.get(url, timeout=5)
    content = BeautifulSoup(response.content, "html.parser")
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34424
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34423
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34411
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34412
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34413
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34414
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34415
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34416
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34417
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34418
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34419
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34420
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34421
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34422
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34425
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34426
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34427
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34428
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34429
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34430
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34431
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34432
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34433
# https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34434

# %%
Result=pd.DataFrame()
races_urls = ['https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34331','https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34385','https://www.fis-ski.com/DB/general/results.html?sectorcode=CC&raceid=34381']
for url in races_urls:
    labels=[]
    response = requests.get(url, timeout=5)
    content = BeautifulSoup(response.content, "html.parser")
    event = content.find('div', class_='event-header__kind').getText()
    place = content.find('h1', class_ = re.compile('heading.*')).getText()
    date = content.find('span', class_='date__short').getText()
    result_type = content.find('div',class_ = 'event-header__subtitle').getText()
    print(event,place,date,result_type)
    tableHeader = content.find('div',{ "data-boundary" : "#events-info-results"})
    rows = tableHeader.find_all('div', class_ = re.compile('g-lg.*'))

    column_headers = [
    row.get_text() for row in rows
        ]

    data = content.find('div',id='events-info-results')
    data_rows = data.find_all('a', class_ = re.compile('table-row'))


    player_data_02 = []  # create an empty list to hold all the data

    for i in range(len(data_rows)):  # for each table row
            player_row = []  # create an empty list for each pick/player

            # for each table data element from each table row
            for row in data_rows[i].findAll('div', class_ = re.compile('g-lg.*')):
                # get the text content and append to the player_row
                player_row.append(row.getText())

            # then append each pick/player to the player_data matrix
            player_data_02.append(player_row)



    df = pd.DataFrame(player_data_02, columns=column_headers)
      
    df['Event'] = event
    df['Place'] = place
    df['Date'] = date
    df['Result Type'] = result_type
    df['Season'] = season

    frames = [Result, df]
    Result = pd.concat(frames,sort=False)
    
Result.info()
# Out:
# Women's SP  C Qual Ruka (FIN) Nov 29, 2019 Sprint Qualification
# Women's Teamsprint Finals Dresden (GER) Jan 12, 2020 World Cup
# Women's SP  F Final Dresden (GER) Jan 11, 2020 World Cup
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         229 non-null    object
#  1   Bib          229 non-null    object
#  2   FIS code     229 non-null    object
#  3   Athlete      154 non-null    object
#  4   Year         229 non-null    object
#  5   Nation       229 non-null    object
#  6   Time         92 non-null     object
#  7   Diff. Time   152 non-null    object
#  8   FIS Points   92 non-null     object
#  9   Event        229 non-null    object
#  10  Place        229 non-null    object
#  11  Date         229 non-null    object
#  12  Result Type  229 non-null    object
#  13  Name         75 non-null     object
#  14  Tot. Time    60 non-null     object
# dtypes: object(15)
# memory usage: 28.6+ KB

# %%
Result
# Out:
#    Rank Bib FIS code                                            Athlete  Year  \
# 0     1  31  3295157  \n                                SCARDONI Luc...  1991
# 1     2  12  3535320  \n                                MAUBET BJORN...  1989
# 2     3  23  3295193  \n                                LAURENT Gret...  1992
# 3     4   4  3535304  \n                                CALDWELL Sop...  1990
# 4     5  27  3426112  \n                                STENSETH Ane...  1995
# ..  ...  ..      ...                                                ...   ...
# 57   58  34  3486177  \n                                BAYAZITOVA A...  1998
# 58   59  61  3045070  \n                                WRIGHT Casey...  1994
# 59   60  29  3125106  \n                                JIALIN Bayan...  1999
# 60   61  62  3695082  \n                                KROL Yuliia ...  1998
# 61   62  52  3385016  \n                                MALEC Vedran...  1990
#
#                Nation     Time Diff. Time FIS Points                Event  \
# 0   \n\n\n\n\nITA\n\n  3:03.01    3:03.01       0.00   Women's SP  C Qual
# 1   \n\n\n\n\nUSA\n\n  3:04.16      +1.15       7.54   Women's SP  C Qual
# 2   \n\n\n\n\nITA\n\n  3:05.15      +2.14      14.03   Women's SP  C Qual
# 3   \n\n\n\n\nUSA\n\n  3:05.62      +2.61      17.11   Women's SP  C Qual
# 4   \n\n\n\n\nNOR\n\n  3:05.67      +2.66      17.44   Women's SP  C Qual
# ..                ...      ...        ...        ...                  ...
# 57  \n\n\n\n\nRUS\n\n      NaN        NaN        NaN  Women's SP  F Final
# 58  \n\n\n\n\nAUS\n\n      NaN        NaN        NaN  Women's SP  F Final
# 59  \n\n\n\n\nCHN\n\n      NaN        NaN        NaN  Women's SP  F Final
# 60  \n\n\n\n\nUKR\n\n      NaN        NaN        NaN  Women's SP  F Final
# 61  \n\n\n\n\nCRO\n\n      NaN        NaN        NaN  Women's SP  F Final
#
#             Place          Date           Result Type Name Tot. Time
# 0      Ruka (FIN)  Nov 29, 2019  Sprint Qualification  NaN       NaN
# 1      Ruka (FIN)  Nov 29, 2019  Sprint Qualification  NaN       NaN
# 2      Ruka (FIN)  Nov 29, 2019  Sprint Qualification  NaN       NaN
# 3      Ruka (FIN)  Nov 29, 2019  Sprint Qualification  NaN       NaN
# 4      Ruka (FIN)  Nov 29, 2019  Sprint Qualification  NaN       NaN
# ..            ...           ...                   ...  ...       ...
# 57  Dresden (GER)  Jan 11, 2020             World Cup  NaN       NaN
# 58  Dresden (GER)  Jan 11, 2020             World Cup  NaN       NaN
# 59  Dresden (GER)  Jan 11, 2020             World Cup  NaN       NaN
# 60  Dresden (GER)  Jan 11, 2020             World Cup  NaN       NaN
# 61  Dresden (GER)  Jan 11, 2020             World Cup  NaN       NaN
#
# [229 rows x 15 columns]

# %%
Result = Result.reset_index(drop=True)
Result['Nation']= Result['Nation'].str.replace('\n','')
Result['Athlete']= Result['Athlete'].str.replace('\n','')
Result['Athlete']= Result['Athlete'].str.strip()

columns=['Name','Tot. Time','(Rk.)','FIS points Time']
Result.drop(columns, inplace=True, axis=1)


Result
# Out:
#     Rank Bib FIS code                  Athlete  Year Nation     Time  \
# 0      1  31  3295157           SCARDONI Lucia  1991    ITA  3:03.01
# 1      2  12  3535320    MAUBET BJORNSEN Sadie  1989    USA  3:04.16
# 2      3  23  3295193            LAURENT Greta  1992    ITA  3:05.15
# 3      4   4  3535304          CALDWELL Sophie  1990    USA  3:05.62
# 4      5  27  3426112  STENSETH Ane Appelkvist  1995    NOR  3:05.67
# ..   ...  ..      ...                      ...   ...    ...      ...
# 224   58  34  3486177          BAYAZITOVA Aida  1998    RUS      NaN
# 225   59  61  3045070             WRIGHT Casey  1994    AUS      NaN
# 226   60  29  3125106            JIALIN Bayani  1999    CHN      NaN
# 227   61  62  3695082              KROL Yuliia  1998    UKR      NaN
# 228   62  52  3385016            MALEC Vedrana  1990    CRO      NaN
#
#     Diff. Time FIS Points                Event          Place          Date  \
# 0      3:03.01       0.00   Women's SP  C Qual     Ruka (FIN)  Nov 29, 2019
# 1        +1.15       7.54   Women's SP  C Qual     Ruka (FIN)  Nov 29, 2019
# 2        +2.14      14.03   Women's SP  C Qual     Ruka (FIN)  Nov 29, 2019
# 3        +2.61      17.11   Women's SP  C Qual     Ruka (FIN)  Nov 29, 2019
# 4        +2.66      17.44   Women's SP  C Qual     Ruka (FIN)  Nov 29, 2019
# ..         ...        ...                  ...            ...           ...
# 224        NaN        NaN  Women's SP  F Final  Dresden (GER)  Jan 11, 2020
# 225        NaN        NaN  Women's SP  F Final  Dresden (GER)  Jan 11, 2020
# 226        NaN        NaN  Women's SP  F Final  Dresden (GER)  Jan 11, 2020
# 227        NaN        NaN  Women's SP  F Final  Dresden (GER)  Jan 11, 2020
# 228        NaN        NaN  Women's SP  F Final  Dresden (GER)  Jan 11, 2020
#
#               Result Type Name Tot. Time
# 0    Sprint Qualification  NaN       NaN
# 1    Sprint Qualification  NaN       NaN
# 2    Sprint Qualification  NaN       NaN
# 3    Sprint Qualification  NaN       NaN
# 4    Sprint Qualification  NaN       NaN
# ..                    ...  ...       ...
# 224             World Cup  NaN       NaN
# 225             World Cup  NaN       NaN
# 226             World Cup  NaN       NaN
# 227             World Cup  NaN       NaN
# 228             World Cup  NaN       NaN
#
# [229 rows x 15 columns]

# %%
if os.path.isfile('extract/raw-data.csv'):
    os.remove('extract/raw-data.csv')
Result.to_csv('extract/raw-data.csv',encoding='utf-8')
