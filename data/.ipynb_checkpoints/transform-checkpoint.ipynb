# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import json
import numpy as np
import csv

# %%
Result = pd.read_csv('extract/raw-data.csv')
columns=['Unnamed: 0']
Result.drop(columns, inplace=True, axis=1)
Result
# Out:
#       Rank   Bib  FIS code                  Athlete    Year Nation       Time  \
# 0      1.0  31.0   3295157           SCARDONI Lucia  1991.0    ITA    3:03.01
# 1      2.0  12.0   3535320    MAUBET BJORNSEN Sadie  1989.0    USA    3:04.16
# 2      3.0  23.0   3295193            LAURENT Greta  1992.0    ITA    3:05.15
# 3      4.0   4.0   3535304          CALDWELL Sophie  1990.0    USA    3:05.62
# 4      5.0  27.0   3426112  STENSETH Ane Appelkvist  1995.0    NOR    3:05.67
# ...    ...   ...       ...                      ...     ...    ...        ...
# 6731  47.0  39.0   3530772      LUSTGARTEN Benjamin  1992.0    USA  2:21:25.4
# 6732  48.0  52.0   3181007           VUORELA Markus  1996.0    FIN  2:22:37.9
# 6733  49.0  56.0   3120063             SHANG Jincai  1993.0    CHN  2:23:13.9
# 6734  50.0  38.0   3530711              MARTIN Adam  1994.0    USA  2:23:15.4
# 6735  51.0  37.0   3290504            VENTURA Paolo  1996.0    ITA  2:26:07.3
#
#      Diff. Time  FIS Points               Event       Place          Date  \
# 0       3:03.01        0.00  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 1         +1.15        7.54  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 2         +2.14       14.03  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 3         +2.61       17.11  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 4         +2.66       17.44  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# ...         ...         ...                 ...         ...           ...
# 6731   +13:20.1      145.75   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6732   +14:32.6      158.96   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6733   +15:08.6      165.52   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6734   +15:10.1      165.79   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6735   +18:02.0      197.10   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
#
#                Result Type  Season
# 0     Sprint Qualification    2020
# 1     Sprint Qualification    2020
# 2     Sprint Qualification    2020
# 3     Sprint Qualification    2020
# 4     Sprint Qualification    2020
# ...                    ...     ...
# 6731             World Cup    2020
# 6732             World Cup    2020
# 6733             World Cup    2020
# 6734             World Cup    2020
# 6735             World Cup    2020
#
# [6736 rows x 14 columns]

# %%
Result.replace(r'^\s*$', np.nan, regex=True, inplace=True)
Result['Rank']=Result['Rank'].fillna(method='ffill')
Result.info()
Result
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         6736 non-null   float64
#  1   Bib          6385 non-null   float64
#  2   FIS code     6736 non-null   int64
#  3   Athlete      5885 non-null   object
#  4   Year         6481 non-null   float64
#  5   Nation       6140 non-null   object
#  6   Time         4366 non-null   object
#  7   Diff. Time   4555 non-null   object
#  8   FIS Points   4015 non-null   float64
#  9   Event        6736 non-null   object
#  10  Place        6736 non-null   object
#  11  Date         6736 non-null   object
#  12  Result Type  6736 non-null   object
#  13  Season       6736 non-null   int64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 736.9+ KB
#       Rank   Bib  FIS code                  Athlete    Year Nation       Time  \
# 0      1.0  31.0   3295157           SCARDONI Lucia  1991.0    ITA    3:03.01
# 1      2.0  12.0   3535320    MAUBET BJORNSEN Sadie  1989.0    USA    3:04.16
# 2      3.0  23.0   3295193            LAURENT Greta  1992.0    ITA    3:05.15
# 3      4.0   4.0   3535304          CALDWELL Sophie  1990.0    USA    3:05.62
# 4      5.0  27.0   3426112  STENSETH Ane Appelkvist  1995.0    NOR    3:05.67
# ...    ...   ...       ...                      ...     ...    ...        ...
# 6731  47.0  39.0   3530772      LUSTGARTEN Benjamin  1992.0    USA  2:21:25.4
# 6732  48.0  52.0   3181007           VUORELA Markus  1996.0    FIN  2:22:37.9
# 6733  49.0  56.0   3120063             SHANG Jincai  1993.0    CHN  2:23:13.9
# 6734  50.0  38.0   3530711              MARTIN Adam  1994.0    USA  2:23:15.4
# 6735  51.0  37.0   3290504            VENTURA Paolo  1996.0    ITA  2:26:07.3
#
#      Diff. Time  FIS Points               Event       Place          Date  \
# 0       3:03.01        0.00  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 1         +1.15        7.54  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 2         +2.14       14.03  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 3         +2.61       17.11  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 4         +2.66       17.44  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# ...         ...         ...                 ...         ...           ...
# 6731   +13:20.1      145.75   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6732   +14:32.6      158.96   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6733   +15:08.6      165.52   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6734   +15:10.1      165.79   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6735   +18:02.0      197.10   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
#
#                Result Type  Season
# 0     Sprint Qualification    2020
# 1     Sprint Qualification    2020
# 2     Sprint Qualification    2020
# 3     Sprint Qualification    2020
# 4     Sprint Qualification    2020
# ...                    ...     ...
# 6731             World Cup    2020
# 6732             World Cup    2020
# 6733             World Cup    2020
# 6734             World Cup    2020
# 6735             World Cup    2020
#
# [6736 rows x 14 columns]

# %%
Result['Rank'] = Result['Rank'].astype('int')
Result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         6736 non-null   int64
#  1   Bib          6385 non-null   float64
#  2   FIS code     6736 non-null   int64
#  3   Athlete      5885 non-null   object
#  4   Year         6481 non-null   float64
#  5   Nation       6140 non-null   object
#  6   Time         4366 non-null   object
#  7   Diff. Time   4555 non-null   object
#  8   FIS Points   4015 non-null   float64
#  9   Event        6736 non-null   object
#  10  Place        6736 non-null   object
#  11  Date         6736 non-null   object
#  12  Result Type  6736 non-null   object
#  13  Season       6736 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 736.9+ KB

# %%
def technique(Event):
    if "C/F" in Event:
        return "Skiathlon"
    elif "C" in Event:
        return 'Classic'
    elif "F" in Event:
        return 'Free'
    return 'Team'

def gender(Event):
    if "Women" in Event:
        return "Women"
    return "Men"

def team(Event):
    if "Team" in Event or "Rel" in Event:
        return "Team"
    return "Individual"

def sprintdistance(Event):
    if "SP" in Event or "sprint" in Event:
        return "Sprint"
    if "Overall" in Event:
        return "Overall"
    return "Distance"

def distance(Event):
    if "SP" in Event or "sprint" in Event:
        return "Sprint"
    elif "10" in Event:
        return "10"
    elif "15" in Event:
        return "15"
    elif "7.5/7.5" in Event:
        return "7.5/7.5"
    elif "15/15" in Event:
        return "15/15"
    elif "4x" in Event:
        return "Relay"
    elif "30" in Event:
        return "30"
    elif "50" in Event:
        return "50"
    elif "Overall" in Event:
        return "Overall"
    return "Other"

def points(ResultType):
    if "Overall" in ResultType:
        return 0
    elif "World Cup" in ResultType:
        return 1
    return 0

        
Result['Technique']=Result.apply(lambda x: technique(x['Event']),axis=1)
Result['Gender']=Result.apply(lambda x: gender(x['Event']),axis=1)
Result['Event individual/team']=Result.apply(lambda x: team(x['Event']),axis=1)
Result['Event sprint/distance']=Result.apply(lambda x: sprintdistance(x['Event']),axis=1)
Result['Distance']=Result.apply(lambda x: distance(x['Event']),axis=1)
Result['Points']=Result.apply(lambda x: points(x['Result Type']+x['Event']),axis=1)
Result
#Result.loc[(Result['FIS code']=='3185705') & (Result['Rank']<=3)]
# Out:
#       Rank   Bib  FIS code                  Athlete    Year Nation       Time  \
# 0        1  31.0   3295157           SCARDONI Lucia  1991.0    ITA    3:03.01
# 1        2  12.0   3535320    MAUBET BJORNSEN Sadie  1989.0    USA    3:04.16
# 2        3  23.0   3295193            LAURENT Greta  1992.0    ITA    3:05.15
# 3        4   4.0   3535304          CALDWELL Sophie  1990.0    USA    3:05.62
# 4        5  27.0   3426112  STENSETH Ane Appelkvist  1995.0    NOR    3:05.67
# ...    ...   ...       ...                      ...     ...    ...        ...
# 6731    47  39.0   3530772      LUSTGARTEN Benjamin  1992.0    USA  2:21:25.4
# 6732    48  52.0   3181007           VUORELA Markus  1996.0    FIN  2:22:37.9
# 6733    49  56.0   3120063             SHANG Jincai  1993.0    CHN  2:23:13.9
# 6734    50  38.0   3530711              MARTIN Adam  1994.0    USA  2:23:15.4
# 6735    51  37.0   3290504            VENTURA Paolo  1996.0    ITA  2:26:07.3
#
#      Diff. Time  FIS Points               Event       Place          Date  \
# 0       3:03.01        0.00  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 1         +1.15        7.54  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 2         +2.14       14.03  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 3         +2.61       17.11  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# 4         +2.66       17.44  Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019
# ...         ...         ...                 ...         ...           ...
# 6731   +13:20.1      145.75   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6732   +14:32.6      158.96   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6733   +15:08.6      165.52   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6734   +15:10.1      165.79   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
# 6735   +18:02.0      197.10   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020
#
#                Result Type  Season Technique Gender Event individual/team  \
# 0     Sprint Qualification    2020   Classic  Women            Individual
# 1     Sprint Qualification    2020   Classic  Women            Individual
# 2     Sprint Qualification    2020   Classic  Women            Individual
# 3     Sprint Qualification    2020   Classic  Women            Individual
# 4     Sprint Qualification    2020   Classic  Women            Individual
# ...                    ...     ...       ...    ...                   ...
# 6731             World Cup    2020   Classic    Men            Individual
# 6732             World Cup    2020   Classic    Men            Individual
# 6733             World Cup    2020   Classic    Men            Individual
# 6734             World Cup    2020   Classic    Men            Individual
# 6735             World Cup    2020   Classic    Men            Individual
#
#      Event sprint/distance Distance  Points
# 0                   Sprint   Sprint       0
# 1                   Sprint   Sprint       0
# 2                   Sprint   Sprint       0
# 3                   Sprint   Sprint       0
# 4                   Sprint   Sprint       0
# ...                    ...      ...     ...
# 6731              Distance       50       1
# 6732              Distance       50       1
# 6733              Distance       50       1
# 6734              Distance       50       1
# 6735              Distance       50       1
#
# [6736 rows x 20 columns]

# %%
athletes=Result[['FIS code','Athlete','Year','Nation']]
athletes=athletes.drop_duplicates()
athletes=athletes.dropna()
athletes.loc[athletes['FIS code']==3295157]
# Out:
#    FIS code         Athlete    Year Nation
# 0   3295157  SCARDONI Lucia  1991.0    ITA

# %%
columns=['Athlete','Year','Nation',]
Result.drop(columns, inplace=True, axis=1)
Result
# Out:
#       Rank   Bib  FIS code       Time Diff. Time  FIS Points  \
# 0        1  31.0   3295157    3:03.01    3:03.01        0.00
# 1        2  12.0   3535320    3:04.16      +1.15        7.54
# 2        3  23.0   3295193    3:05.15      +2.14       14.03
# 3        4   4.0   3535304    3:05.62      +2.61       17.11
# 4        5  27.0   3426112    3:05.67      +2.66       17.44
# ...    ...   ...       ...        ...        ...         ...
# 6731    47  39.0   3530772  2:21:25.4   +13:20.1      145.75
# 6732    48  52.0   3181007  2:22:37.9   +14:32.6      158.96
# 6733    49  56.0   3120063  2:23:13.9   +15:08.6      165.52
# 6734    50  38.0   3530711  2:23:15.4   +15:10.1      165.79
# 6735    51  37.0   3290504  2:26:07.3   +18:02.0      197.10
#
#                    Event       Place          Date           Result Type  \
# 0     Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019  Sprint Qualification
# 1     Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019  Sprint Qualification
# 2     Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019  Sprint Qualification
# 3     Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019  Sprint Qualification
# 4     Women's SP  C Qual  Ruka (FIN)  Nov 29, 2019  Sprint Qualification
# ...                  ...         ...           ...                   ...
# 6731   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020             World Cup
# 6732   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020             World Cup
# 6733   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020             World Cup
# 6734   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020             World Cup
# 6735   Men's 50 km C Mst  Oslo (NOR)  Mar 08, 2020             World Cup
#
#       Season Technique Gender Event individual/team Event sprint/distance  \
# 0       2020   Classic  Women            Individual                Sprint
# 1       2020   Classic  Women            Individual                Sprint
# 2       2020   Classic  Women            Individual                Sprint
# 3       2020   Classic  Women            Individual                Sprint
# 4       2020   Classic  Women            Individual                Sprint
# ...      ...       ...    ...                   ...                   ...
# 6731    2020   Classic    Men            Individual              Distance
# 6732    2020   Classic    Men            Individual              Distance
# 6733    2020   Classic    Men            Individual              Distance
# 6734    2020   Classic    Men            Individual              Distance
# 6735    2020   Classic    Men            Individual              Distance
#
#      Distance  Points
# 0      Sprint       0
# 1      Sprint       0
# 2      Sprint       0
# 3      Sprint       0
# 4      Sprint       0
# ...       ...     ...
# 6731       50       1
# 6732       50       1
# 6733       50       1
# 6734       50       1
# 6735       50       1
#
# [6736 rows x 17 columns]

# %% [markdown]
# Left joinar på Wins på Athlete tabellen.
#
# Räknar endast när Rank=1 och Points=1 vilket betyder att det inte är ett kval eller overall slutresultat.

# %%
KPI = 'Podiums'
GroupBy = 'Points'
Definition = (Result['Rank'] <= 3) & (Result['Points']==1)

if KPI in athletes:
    athletes.drop(KPI, inplace=True, axis=1)

tmp_kpi=Result.loc[Definition]
tmp_kpi=tmp_kpi.groupby('FIS code')[GroupBy].value_counts()

athletes = pd.merge(athletes, tmp_kpi,how='left', on='FIS code')
athletes.rename(columns={GroupBy:KPI}, inplace=True)
athletes[KPI] = athletes[KPI].fillna(0)

athletes
# Out:
#      FIS code                  Athlete    Year Nation  Podiums
# 0     3295157           SCARDONI Lucia  1991.0    ITA      0.0
# 1     3535320    MAUBET BJORNSEN Sadie  1989.0    USA      2.0
# 2     3295193            LAURENT Greta  1992.0    ITA      0.0
# 3     3535304          CALDWELL Sophie  1990.0    USA      2.0
# 4     3426112  STENSETH Ane Appelkvist  1995.0    NOR      0.0
# ..        ...                      ...     ...    ...      ...
# 476   3425896         THEODORSEN Silje  1994.0    NOR      0.0
# 477   3486003          VASILIEVA Lilia  1994.0    RUS      0.0
# 478   3425772      BJOERNSGAARD Marthe  1993.0    NOR      0.0
# 479   3665059             LUKONINA Ina  1994.0    BLR      0.0
# 480   3421269             STOCK Daniel  1992.0    NOR      0.0
#
# [481 rows x 5 columns]

# %%
KPI = 'Wins'
GroupBy = 'Points'
Definition = (Result['Rank'] == 1) & (Result['Points']==1)

if KPI in athletes:
    athletes.drop(KPI, inplace=True, axis=1)

tmp_kpi=Result.loc[Definition]
tmp_kpi=tmp_kpi.groupby('FIS code')[GroupBy].value_counts()

athletes = pd.merge(athletes, tmp_kpi,how='left', on='FIS code')
athletes.rename(columns={GroupBy:KPI}, inplace=True)
athletes[KPI] = athletes[KPI].fillna(0)

athletes
# Out:
#      FIS code                  Athlete    Year Nation  Podiums  Wins
# 0     3295157           SCARDONI Lucia  1991.0    ITA      0.0   0.0
# 1     3535320    MAUBET BJORNSEN Sadie  1989.0    USA      2.0   0.0
# 2     3295193            LAURENT Greta  1992.0    ITA      0.0   0.0
# 3     3535304          CALDWELL Sophie  1990.0    USA      2.0   0.0
# 4     3426112  STENSETH Ane Appelkvist  1995.0    NOR      0.0   0.0
# ..        ...                      ...     ...    ...      ...   ...
# 476   3425896         THEODORSEN Silje  1994.0    NOR      0.0   0.0
# 477   3486003          VASILIEVA Lilia  1994.0    RUS      0.0   0.0
# 478   3425772      BJOERNSGAARD Marthe  1993.0    NOR      0.0   0.0
# 479   3665059             LUKONINA Ina  1994.0    BLR      0.0   0.0
# 480   3421269             STOCK Daniel  1992.0    NOR      0.0   0.0
#
# [481 rows x 6 columns]

# %%
KPI = 'Top 10'
GroupBy = 'Points'
Definition = (Result['Rank'] <= 10) & (Result['Points']==1)

if KPI in athletes:
    athletes.drop(KPI, inplace=True, axis=1)

tmp_kpi=Result.loc[Definition]
tmp_kpi=tmp_kpi.groupby('FIS code')[GroupBy].value_counts()

athletes = pd.merge(athletes, tmp_kpi,how='left', on='FIS code')
athletes.rename(columns={GroupBy:KPI}, inplace=True)
athletes[KPI] = athletes[KPI].fillna(0)

athletes
# Out:
#      FIS code                  Athlete    Year Nation  Podiums  Wins  Top 10
# 0     3295157           SCARDONI Lucia  1991.0    ITA      0.0   0.0     1.0
# 1     3535320    MAUBET BJORNSEN Sadie  1989.0    USA      2.0   0.0    12.0
# 2     3295193            LAURENT Greta  1992.0    ITA      0.0   0.0     1.0
# 3     3535304          CALDWELL Sophie  1990.0    USA      2.0   0.0     9.0
# 4     3426112  STENSETH Ane Appelkvist  1995.0    NOR      0.0   0.0     4.0
# ..        ...                      ...     ...    ...      ...   ...     ...
# 476   3425896         THEODORSEN Silje  1994.0    NOR      0.0   0.0     0.0
# 477   3486003          VASILIEVA Lilia  1994.0    RUS      0.0   0.0     0.0
# 478   3425772      BJOERNSGAARD Marthe  1993.0    NOR      0.0   0.0     0.0
# 479   3665059             LUKONINA Ina  1994.0    BLR      0.0   0.0     0.0
# 480   3421269             STOCK Daniel  1992.0    NOR      0.0   0.0     0.0
#
# [481 rows x 7 columns]

# %%
athletes.info()
Result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 481 entries, 0 to 480
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FIS code  481 non-null    int64
#  1   Athlete   481 non-null    object
#  2   Year      481 non-null    float64
#  3   Nation    481 non-null    object
#  4   Podiums   481 non-null    float64
#  5   Wins      481 non-null    float64
#  6   Top 10    481 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 30.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   6736 non-null   int64
#  1   Bib                    6385 non-null   float64
#  2   FIS code               6736 non-null   int64
#  3   Time                   4366 non-null   object
#  4   Diff. Time             4555 non-null   object
#  5   FIS Points             4015 non-null   float64
#  6   Event                  6736 non-null   object
#  7   Place                  6736 non-null   object
#  8   Date                   6736 non-null   object
#  9   Result Type            6736 non-null   object
#  10  Season                 6736 non-null   int64
#  11  Technique              6736 non-null   object
#  12  Gender                 6736 non-null   object
#  13  Event individual/team  6736 non-null   object
#  14  Event sprint/distance  6736 non-null   object
#  15  Distance               6736 non-null   object
#  16  Points                 6736 non-null   int64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 894.8+ KB

# %%
Result_tmp=Result.loc[Result['Place']=='Ruka (FIN)']
Result_tmp = Result_tmp[['Rank','Bib','FIS code']]
Result_tmp
# Out:
#      Rank   Bib  FIS code
# 0       1  31.0   3295157
# 1       2  12.0   3535320
# 2       3  23.0   3295193
# 3       4   4.0   3535304
# 4       5  27.0   3426112
# ..    ...   ...       ...
# 865    72   NaN   3181015
# 866    73   NaN   3740072
# 867    74   NaN   3660055
# 868    75   NaN   3181098
# 869    76   NaN   3430103
#
# [870 rows x 3 columns]

# %%
# df['Rank']=df['Rank'].astype('int')
# df['Bib']=df['Bib'].astype('int')
# df['FIS code']=df['FIS code'].astype('int')
# df['FIS Points']=df['FIS Points'].astype('float')
# df['Year']=df['Year'].astype('int')

athletes.to_csv('transform/athletes.csv',encoding='utf-8',header=False)
Result_tmp.to_csv('transform/results.csv',encoding='utf-8',header=False)
